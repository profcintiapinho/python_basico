# %% [markdown]
# # CONVERTER XLS PARA CSV

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

read_file = pd.read_excel(r'/content/drive/MyDrive/redacoes_digitadores/bases/Teste_50redacoes.xlsx')
read_file.to_csv (r'/content/drive/MyDrive/redacoes_digitadores/bases/Teste_50redacoes.csv', index = None, header = True)
